# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
# STEP 1: Load dataset
df = pd.read_csv(r'D:\JOB\1 Pricing analyst\AB testing\Projects\2 Multivariate Test (MVT)\mvt_pricing_data.csv')

# %%
df
# Out:
#       user_id  price_point  discount_percent marketing_channel   device  \
# 0           1        24.99                 5            social  desktop
# 1           2        29.99                15             email  desktop
# 2           3        19.99                20             email  desktop
# 3           4        29.99                15             email  desktop
# 4           5        29.99                15            search   mobile
# ...       ...          ...               ...               ...      ...
# 9995     9996        14.99                15             email  desktop
# 9996     9997        19.99                15            social  desktop
# 9997     9998        14.99                 5             email   mobile
# 9998     9999        24.99                 5            social   mobile
# 9999    10000        19.99                 0         affiliate  desktop
#
#      location  gender  age  session_duration  pages_viewed  conversion  \
# 0          UK    male   40             89.75             3           0
# 1          UK    male   32            177.33             6           0
# 2      Canada  female   26             68.27             2           0
# 3          UK   other   57            371.60             0           0
# 4      Canada    male   55            718.36             6           0
# ...       ...     ...  ...               ...           ...         ...
# 9995  Germany  female   42           1074.18             5           1
# 9996  Germany   other   27            109.69             8           0
# 9997       UK   other   22            274.09             3           1
# 9998       UK   other   49            512.49             3           0
# 9999       US   other   49            215.86             2           0
#
#       revenue                 combo
# 0        0.00     P24.99_D5_Csocial
# 1        0.00     P29.99_D15_Cemail
# 2        0.00     P19.99_D20_Cemail
# 3        0.00     P29.99_D15_Cemail
# 4        0.00    P29.99_D15_Csearch
# ...       ...                   ...
# 9995    14.99     P14.99_D15_Cemail
# 9996     0.00    P19.99_D15_Csocial
# 9997    14.99      P14.99_D5_Cemail
# 9998     0.00     P24.99_D5_Csocial
# 9999     0.00  P19.99_D0_Caffiliate
#
# [10000 rows x 13 columns]

# %%
# STEP 2: Create revenue column
df['revenue'] = df['conversion'] * df['price_point']

# %%
# STEP 3: Group by combinations (MVT)
conversion_combo = df.groupby(['price_point', 'discount_percent', 'marketing_channel'])['conversion'].mean().reset_index()
conversion_combo.columns = ['price_point', 'discount_percent', 'marketing_channel', 'conversion_rate']

# %%
revenue_combo = df.groupby(['price_point', 'discount_percent', 'marketing_channel'])['revenue'].mean().reset_index()
revenue_combo.columns = ['price_point', 'discount_percent', 'marketing_channel', 'revenue_per_user']

# %%
mvt_summary = pd.merge(conversion_combo, revenue_combo, on=['price_point', 'discount_percent', 'marketing_channel'])
mvt_summary['combo'] = (
    'Price: $' + mvt_summary['price_point'].astype(str) + ' | ' +
    'Discount: ' + mvt_summary['discount_percent'].astype(str) + '% | ' +
    'Channel: ' + mvt_summary['marketing_channel']
)

# %%
mvt_summary.nlargest(10, 'revenue_per_user')
# Out:
#      price_point  discount_percent marketing_channel  conversion_rate  \
# 106        29.99                 5            direct         0.208333
# 116        29.99                15            direct         0.205128
# 90         24.99                15         affiliate         0.234568
# 114        29.99                10            social         0.184615
# 82         24.99                 5             email         0.221053
# 112        29.99                10             email         0.178082
# 107        29.99                 5             email         0.173333
# 87         24.99                10             email         0.202532
# 77         24.99                 0             email         0.190476
# 96         24.99                20            direct         0.190476
#
#      revenue_per_user                                              combo
# 106          6.247917     Price: $29.99 | Discount: 5% | Channel: direct
# 116          6.151795    Price: $29.99 | Discount: 15% | Channel: direct
# 90           5.861852  Price: $24.99 | Discount: 15% | Channel: affil...
# 114          5.536615    Price: $29.99 | Discount: 10% | Channel: social
# 82           5.524105      Price: $24.99 | Discount: 5% | Channel: email
# 112          5.340685     Price: $29.99 | Discount: 10% | Channel: email
# 107          5.198267      Price: $29.99 | Discount: 5% | Channel: email
# 87           5.061266     Price: $24.99 | Discount: 10% | Channel: email
# 77           4.760000      Price: $24.99 | Discount: 0% | Channel: email
# 96           4.760000    Price: $24.99 | Discount: 20% | Channel: direct

# %%
# STEP 5: Prepare for logistic regression
df['combo'] = (
    'P' + df['price_point'].astype(str) +
    '_D' + df['discount_percent'].astype(str) +
    '_C' + df['marketing_channel']
)

# %%
# STEP 6: One-hot encode categorical variables
df_encoded = pd.get_dummies(df, columns=[
    'price_point', 'discount_percent', 'marketing_channel',
    'device', 'location', 'gender'
], drop_first=True)

# %%
# STEP 7: Define features and target
X = df_encoded.drop(columns=['user_id', 'conversion', 'combo', 'revenue'])
y = df_encoded['conversion']

# %%
# STEP 8: Add constant and ensure numeric types
X = sm.add_constant(X)
X = X.apply(lambda col: col.astype(int) if col.dtype == 'bool' else col)
X = X.apply(pd.to_numeric)

# %%
# STEP 9: Fit logistic regression
model = sm.Logit(y, X).fit(disp=False)

# %%
# STEP 10: Show summary
print(model.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             conversion   No. Observations:                10000
# Model:                          Logit   Df Residuals:                     9976
# Method:                           MLE   Df Model:                           23
# Date:                Tue, 08 Apr 2025   Pseudo R-squ.:                0.002430
# Time:                        12:36:46   Log-Likelihood:                -4213.4
# converged:                       True   LL-Null:                       -4223.6
# Covariance Type:            nonrobust   LLR p-value:                    0.6098
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -1.7723      0.166    -10.652      0.000      -2.098      -1.446
# age                          0.0026      0.002      1.228      0.219      -0.002       0.007
# session_duration          9.927e-05   9.31e-05      1.066      0.287   -8.33e-05       0.000
# pages_viewed                -0.0048      0.014     -0.339      0.735      -0.032       0.023
# price_point_14.99           -0.0703      0.087     -0.810      0.418      -0.240       0.100
# price_point_19.99           -0.0504      0.087     -0.578      0.563      -0.221       0.121
# price_point_24.99           -0.0125      0.086     -0.145      0.885      -0.182       0.157
# price_point_29.99           -0.2737      0.090     -3.036      0.002      -0.450      -0.097
# discount_percent_5           0.0813      0.088      0.924      0.355      -0.091       0.254
# discount_percent_10         -0.0017      0.091     -0.019      0.985      -0.179       0.176
# discount_percent_15          0.0454      0.089      0.510      0.610      -0.129       0.220
# discount_percent_20          0.0258      0.089      0.290      0.772      -0.149       0.201
# marketing_channel_direct     0.0139      0.087      0.160      0.873      -0.156       0.184
# marketing_channel_email      0.0497      0.087      0.569      0.569      -0.122       0.221
# marketing_channel_search    -0.0268      0.088     -0.304      0.761      -0.200       0.146
# marketing_channel_social    -0.0829      0.090     -0.924      0.355      -0.259       0.093
# device_mobile                0.0153      0.069      0.223      0.823      -0.119       0.150
# device_tablet               -0.0346      0.069     -0.504      0.614      -0.169       0.100
# location_Canada             -0.0926      0.089     -1.044      0.296      -0.266       0.081
# location_Germany            -0.0560      0.088     -0.636      0.525      -0.229       0.117
# location_UK                 -0.0198      0.086     -0.231      0.818      -0.188       0.149
# location_US                 -0.0536      0.088     -0.608      0.543      -0.226       0.119
# gender_male                  0.0304      0.069      0.441      0.659      -0.105       0.166
# gender_other                 0.0418      0.069      0.604      0.546      -0.094       0.177
# ============================================================================================
